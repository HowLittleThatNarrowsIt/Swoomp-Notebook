# %%
# !wget https://github.com/HowLittleThatNarrowsIt/Swoomp/raw/refs/heads/main/swoomp.zip > /dev/null 2>&1

# %%
# %%capture
# !unzip swoomp.zip > /dev/null 2>&1

# %%
# %%capture
# %cd /content/

# %%
# !make

# %%
# !./main --size 176000000
